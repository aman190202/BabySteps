# %% [markdown]
# <a href="https://colab.research.google.com/github/aman190202/BabySteps/blob/main/Predict_pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
x=list(map(int,input("ENTER THE VALUES OF X ").split()))
y=list(map(int,input("ENTER THE VALUES OF FUNCTION OF X ").split()))
x=np.array(x)
model=tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
y=np.array(y)
i=int(input("ENTER THE VALUE OF X FOR WHICH YOU WANT TO PREDICT THE VLAUE OF F(X) "))
model.fit(x,y,epochs=500)
print(model.predict([i]))
# Out:
# ENTER THE VALUES OF X 1 2 3 4 5 6 7 8 9
# ENTER THE VALUES OF FUNCTION OF X 8 11 14 17 20 23 26 29 32
# ENTER THE VALUE OF X FOR WHICH YOU WANT TO PREDICT THE VLAUE OF F(X) 10
# Epoch 1/500
# 1/1 [==============================] - 0s 182ms/step - loss: 538.4899
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 69.7395
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 12.0347
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9062
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0011
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8618
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8171
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7842
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7529
# Epoch 10/500
# ...
